# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/drive/MyDrive/Capstone B3/Phase 3/datasets/merged_df.csv") 
df.sample(3)
# Out:
#                                       Quesh  Quesh Date  Avg Rating  \
# 57                       What matters most?  2021-12-25        4.00
# 7   What Super Bowl commercial do you love?  2022-02-13        3.72
# 98    How has November been for you so far?  2021-11-14        4.33
#
#     Total Respo  Type  sent_ans  sent_quesh  charcount
# 57           19     2  3.473684         1.0  31.684211
# 7            18     2  2.055556         6.0  60.888889
# 98            9     2  5.111111         0.0  56.444444

# %%
# Labels are the values we want to predict
labels = np.array(df['Avg Rating'])
# Remove the labels from the features
# axis 1 refers to the columns
features= df.drop(['Quesh','Quesh Date','Avg Rating','Total Respo','Type','sent_ans'], axis = 1)
# Saving feature names for later use
feature_list = list(features.columns)
# Convert to numpy array
train_features = np.array(features)

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
# test = pd.read_csv("/content/drive/MyDrive/Capstone B3/Phase 3/datasets/100 Quesh - Team B3.csv") 
# test.sample(3)
# Out:
#     id                                              quesh
# 35  36          Sea or mountain, which one do you prefer?
# 33  34  Regardless of the distance, do you prefer to d...
# 16  17                         Cardio or weight lifting?

# %%
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# %%
rf.fit(train_features, train_labels);

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.39 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 90.25 %.
